# %%
from bert import QA
import os

import json
import numpy as np
import tensorflow as tf
import matplotlib
import subprocess

matplotlib.use('Agg')

import networkx as nx
import json
import argparse
import matplotlib.pyplot as plt
import random
import string

import os
from nltk import tokenize
from nltk.corpus import stopwords

# %%
# import nltk
# nltk.download('stopwords')
# nltk.download('punkt')

# %%
data_dir = "../../../data"
# filename = 'zelda-botw'
# filename = 'resolved_zelda_botw'
# filename = 'rapunzel'
# filename = 'resolved_rapunzel'
filename = '01_the_fellowship_of_the_ring'
# filename = '02_the_two_towers'
# filename = '03_the_return_of_the_king'
# filename = 'little-red-riding-hood'

# %%
def readGraph(file):
    with open(file, 'r') as fp:
        # G = nx.parse_edgelist(, nodetype = int)

        dump = fp.read()
        j = json.loads(dump)
        locs = j.keys()
        objs = []
        for loc in j.values():
            objs += loc['objects']
    return locs, objs, []

location_primer = "Where is the location in the story?"
character_primer = "Who is somebody in the story?"
object_primer = "What is an object in the story?"

loc2loc_templates = ["What location is next to {} in the story?"]

loc2obj_templates = ["What is in {} in the story?", ]
obj2loc_templates = ["What location is {} in the story?", ]

loc2char_templates = ["Who is in {} in the story?", ]
char2loc_templates = ["What location is {} in the story?", ]

obj2char_templates = ["Who has {} in the story?", ]

articles = set(stopwords.words('english'))

# %%
class World:
    def __init__(self, args):
        '''
        Initialize the world KG with the given entities and relations, and set up arguments.
        params:
            `locs`: list of locations
            `chars`: list of characters
            `objs`: list of objects
            `relations`: list of relations
            `args`: arguments
        '''
        self.graph = nx.Graph()  # create base NX graph
        self.current_graph = nx.Graph()  # create context NX graph

        self.entities = {  # dictionary of location, object and character entites
            'locations': set(),
            'objects': set(),
            'characters': set()
        }
        self.relations = []  # list of relations
        self.plots = []  # list of plots

        random.seed(args.seed)  # set seed for reproducibility

        self.nsamples = args.nsamples
        self.write_sfdp = args.write_sfdp
        self.context_lines = args.context_lines  # Number of lines of story to read at once
        
        self.load_cutoffs(args.cutoffs)  # load cutoffs from parameter
        self.load_story(args.input_text)  # load story from parameter 
        self.next_context()  # load first context lines      

        self.model = QA('model/albert-large-squad')


    def load_cutoffs(self, cutoffs):
        '''
        Load cutoffs from parameter.
        params:
            `cutoffs`: either a string ['`fairy`', '`mystery`'] or 
            a list of 3 cutoff decimals for [character, location, object] respectively.
        '''
        if cutoffs == 'fairy':
            self.cutoffs = [6.5, -7, -5]  # fairy
        elif cutoffs == 'mystery':
            self.cutoffs = [3.5, -7.5, -6]  # mystery
        else:
            self.cutoffs = [float(i) for i in cutoffs.split()]
            assert len(self.cutoffs) == 3


    def load_story(self, input_text):
        '''
        Load story from parameter.
        params:
            `input_text`: path to story text file
        '''
        with open(input_text, 'r') as f:
            doc = f.readlines()
            doc = ' '.join([x.strip() for x in doc])

        self.story = tokenize.sent_tokenize(doc)  # split into sentences
        self.remaining_story = self.story
    
    def next_context(self):
        '''
        Load the next `context_lines` lines of the story.
        '''
        if self.context_lines == 'all':
            self.context = ' '.join(self.remaining_story)
            self.remaining_story = []
        else:
            self.context = ' '.join(self.remaining_story[:self.context_lines])
            self.remaining_story = self.remaining_story[self.context_lines:]
        self.unmasked_context = self.context


    def is_connected(self):
        '''
        Check if the current world graph is connected.
        '''
        return len(list(nx.connected_components(self.graph))) == 1


    def query(self, context, query, nsamples=10, cutoff=8):
        '''
        Query the model for the top `nsamples` candidates for the given `query`.
        params:
            `query`: query string
            `nsamples`: maximum number of candidates to return
            `cutoff`: cutoff for the model
        '''
        return self.model.predictTopK(context, query, nsamples, cutoff)


    def generateNeighbors(self, nsamples=100):
        '''
        Retrieve relation candidates for each entity in the world graph.
        params:
            `nsamples`: maximum number of candidates to return
        '''
        self.candidates = {}
        for u in self.current_graph.nodes:
            self.candidates[u] = {}
            if self.current_graph.nodes[u]['type'] == "location":
                self.candidates[u]['location'] = self.query(self.context, random.choice(loc2loc_templates).format(u), nsamples, self.cutoffs[1])
                self.candidates[u]['object'] = self.query(self.context, random.choice(loc2obj_templates).format(u), nsamples, self.cutoffs[2])
                self.candidates[u]['character'] = self.query(self.context, random.choice(loc2char_templates).format(u), nsamples,self.cutoffs[0])
            if self.current_graph.nodes[u]['type'] == "object":
                self.candidates[u]['location'] = self.query(self.context, random.choice(obj2loc_templates).format(u), nsamples, self.cutoffs[1])
                self.candidates[u]['character'] = self.query(self.context, random.choice(obj2char_templates).format(u), nsamples, self.cutoffs[0])
            if self.current_graph.nodes[u]['type'] == "character":
                self.candidates[u]['location'] = self.query(self.context, random.choice(char2loc_templates).format(u), nsamples, self.cutoffs[1])


    def relatedness(self, u, v):
        '''
        Compute the relatedness between two entities. Calculated as :math:`P(x,u) = [p(x,u)+o(u,x)]/2`
        params:
            `u`: entity 1
            `v`: entity 2
        '''
        s = self.get_rel_prob(u, v) 
        s += self.get_rel_prob(v, u)
        return s


    def get_rel_prob(self, u, v):
        s = 0
        v_type = self.current_graph.nodes[v]['type']
        if u not in self.candidates or v_type not in self.candidates[u]:
            return s
        u2v, probs = self.candidates[u][v_type]
        if u2v is not None:
            for c, p in zip(u2v, probs):
                a = set(c.text.split()).difference(articles)
                b = set(v.split()).difference(articles)

                # find best intersect
                best_intersect = 0
                for x in self.current_graph.nodes:
                    xx = set(x.split()).difference(articles)
                    best_intersect = max(best_intersect, len(a.intersection(xx)))

                # increment if answer is best match BoW
                if len(a.intersection(b)) == best_intersect:
                    s += len(a.intersection(b)) * p
        return s


    def extractEntity(self, query, threshold=0.05, cutoff=0):
        '''
        Extract all entities from a query result.
        params:
            `query`: query string
            `threshold`: minimum probability for a candidate to be considered
            `cutoff`: cutoff for the model
        '''
        preds, probs = self.query(self.context, query, self.nsamples, cutoff)

        if preds is None:
            print("NO ANSWER FOUND")
            return None, 0

        for pred, prob in zip(preds, probs):
            t = pred.text
            p = prob
            print('> ', t, p)
            if len(t) < 1:
                continue
            if p > threshold and "MASK" not in t:
                # find a more minimal candidate if possible
                for pred, prob in zip(preds, probs):
                    if t != pred.text and pred.text in t and prob > threshold and len(pred.text) > 2:
                        t = pred.text
                        p = prob
                        break

                t = t.strip(string.punctuation)
                remove = t

                # take out leading articles for cleaning
                words = t.split()
                if words[0].lower() in articles:
                    remove = " ".join(words[1:])
                    words[0] = words[0].lower()
                    t = " ".join(words[1:])
                if remove.strip() == '':
                    print("NO ANSWER FOUND")
                    return None, 0
                print(remove)

                self.context = self.context.replace(remove, '[MASK]').replace('  ', ' ').replace(' .', '.')
                return t, p

        return None, 0


    def generate(self, filename=None):
        '''
        Generate the world graph from the entire story by parsing it # `context_lines` at a time.
        Extracts entities, relations between entities and potential plots.
        params:
            `filename`: path of file to save extracted entities as (JSON)
        '''
        # set initial threshold
        threshold = 0.05

        while len(self.context) != 0:
            print(f'Current context: {self.context}')

            # add locations
            locs = self.extract('locations', location_primer, threshold, self.cutoffs[1])
            # add objects
            objs = self.extract('objects', object_primer, threshold, self.cutoffs[2])
            # add characters
            chars = self.extract('characters', character_primer, threshold, self.cutoffs[0])
            
            self.current_graph.clear()
            self.current_graph.add_nodes_from(locs, type='location', fillcolor="yellow", style="filled")
            self.current_graph.add_nodes_from(objs, type='object', fillcolor="white", style="filled")
            self.current_graph.add_nodes_from(chars, type='character', fillcolor="orange", style="filled")
            
            self.context = self.unmasked_context
            self.autocomplete()
            
            self.entities['locations'].update(locs)
            self.entities['objects'].update(objs)
            self.entities['characters'].update(chars)
            self.next_context()
            print('-' * 20 + '\n')

        self.entities['locations'] = list(self.entities['locations'])
        self.entities['objects'] = list(self.entities['objects'])
        self.entities['characters'] = list(self.entities['characters'])
        self.entities['relations'] = self.relations
        self.entities['plots'] = self.plots
        if filename is not None:
            with open(filename, 'w') as f:
                json.dump(self.entities, f, indent=4, sort_keys=False)


    def extract(self, entity_type, primer, threshold, cutoff):
        entity_list = []
        print('-' * 5 + f'\t{entity_type}\t' + '-' * 5)
        t, _ = self.extractEntity(primer, threshold=threshold, cutoff=cutoff)
        while t is not None and len(t) > 1:
            entity_list.append(t)
            t, _ = self.extractEntity(primer, threshold=threshold, cutoff=cutoff)
        print('-' * 20 + '\n')
        self.context = self.unmasked_context
        return entity_list


    def autocomplete(self):
        '''
        Autocomplete the current contextual graph by adding relations between entities.
        '''
        self.generateNeighbors(self.nsamples)
        print('-' * 5 + '\trelations\t' + '-' * 5)
        entities = list(self.current_graph.nodes)
        best = (-1, '', '')

        for u in entities:
            u_type = self.current_graph.nodes[u]['type']
            # print(f'Searching relations for {u}')
            for v in list(self.current_graph.nodes):
                v_type = self.current_graph.nodes[v]['type']
                if u == v or (u_type != 'location' and u_type == v_type):
                    continue
                uvrel = self.relatedness(u, v)
                best = max(best, (uvrel, v, v_type))
            
            s, v, v_type = best

            if s <= 0:
                # print(f'No relations found for {u}')
                continue
                    
            if u_type == 'location':
                if v_type == 'location':
                    rel_type = "connected to"
                else:
                    rel_type = "located in"
            else:
                rel_type = "has"
            
            self.check_and_add_world_relation(v, u, rel_type)            


    def check_and_add_world_relation(self, v, u, rel_type):
        '''
        Check if the relation is already present in the graph. 
        If present, add to plot graph, otherwise normally add to world graph
        '''
        u_type = self.current_graph.nodes[u]['type']
        v_type = self.current_graph.nodes[v]['type']

        if u not in self.graph:
            self.graph.add_node(u, type=u_type)
        if v not in self.graph:
            self.graph.add_node(v, type=v_type)

        if u_type == 'location':
            if v_type == 'location':
                # if both are location, just add it the relation
                rel_type = 'connected to'
                rel_triplet = (v, rel_type, u)
                print(f'Adding relation: {rel_triplet}')
                self.relations.append(rel_triplet)
                self.graph.add_edge(v, u, label=rel_type)
            else:
                # u is location, v is char/obj
                rel_type = 'located in'
                rel_triplet = (v, rel_type, u)
                print(f'Adding relation: {rel_triplet}')
                for c_node in self.graph[v]:
                    existing_label = self.graph[v][c_node]['label']
                    if existing_label == rel_type:
                        print(f'Found existing relation: {v}, {rel_type}, {c_node}')
                        if c_node != u:
                            # if v is 'located in' some other location (c_node) before this point,
                            # v's location is changed, put it as an event
                            print(f'Updating new relation: {rel_triplet}')
                            self.plots.append({'before': (v, existing_label, c_node), 'after': rel_triplet})
                self.graph.add_edge(v, u, label=rel_type)
                self.relations.append(rel_triplet)
        
        elif u_type == 'charater' and v_type == 'object':
            rel_type = 'has'
            rel_triplet = (u, rel_type, v)
            print(f'Adding relation: {rel_triplet}')
            for c_node in self.graph[v]:
                existing_label = self.graph[v][c_node]['label']
                if existing_label == rel_type:
                    print(f'Found existing relation: {c_node}, {rel_type}, {v}')
                    if c_node != u:
                        # if some other char (c_node) has v before this point, 
                        # v's ownership has changed, put it as event
                        print(f'Updating new relation: {rel_triplet}')
                        self.plots.append({'before': (c_node, existing_label, v), 'after': rel_triplet})
            self.graph.add_edge(v, u, label=rel_type)
            self.relations.append(rel_triplet)
        
        elif u_type == 'object' and v_type == 'character':
            rel_type = 'has'
            rel_triplet = (v, rel_type, u)
            print(f'Adding relation: {rel_triplet}')
            for c_node in self.graph[u]:
                existing_label = self.graph[u][c_node]['label']
                if existing_label == rel_type:
                    print(f'Found existing relation: {v}, {rel_type}, {c_node}')
                    if c_node != u:
                        # if some other char (c_node) has u before this point, 
                        # u's ownership has changed, put it as event
                        print(f'Updating new relation: {rel_triplet}')
                        self.plots.append({'before': (v, existing_label, c_node), 'after': rel_triplet})
            self.graph.add_edge(v, u, label=rel_type)
            self.relations.append(rel_triplet)
            
        elif v_type == 'location':
            # u is char/obj, v is location
            rel_type = 'located in'
            rel_triplet = (u, rel_type, v)
            print(f'Adding relation: {rel_triplet}')
            for c_node in self.graph[u]:
                existing_label = self.graph[u][c_node]['label']
                if existing_label == rel_type:
                    print(f'Found existing relation: {u}, {rel_type}, {c_node}')
                    if c_node != v:
                        # if u is 'located in' some other location (c_node) before this point,
                        # u's location is changed, put it as an event
                        print(f'Updating new relation: {rel_triplet}')
                        self.plots.append({'before': (u, existing_label, c_node), 'after': rel_triplet})
            self.graph.add_edge(v, u, label=rel_type)
            self.relations.append(rel_triplet)


    def export(self, filename="graph.dot"):
        nx.nx_pydot.write_dot(self.graph, filename)
        nx.write_gml(self.graph, "graph.gml", stringizer=None)


    def draw(self, filename="./graph.svg"):
        self.export()

        if self.write_sfdp:
            cmd = "sfdp -x -Goverlap=False -Tsvg graph.dot".format(filename)
            returned_value = subprocess.check_output(cmd, shell=True)
            with open(filename, 'wb') as f:
                f.write(returned_value)
            cmd = "inkscape -z -e {}.png {}.svg".format(filename[:-4], filename[:-4])
            returned_value = subprocess.check_output(cmd, shell=True)
        else:
            nx.draw(self.graph, with_labels=True)
            plt.savefig(filename[:-4] + '.png')

# %%
class Args:
    def __init__(self, args):
        self.input_text = args['input_text']
        self.seed = args['seed']
        self.nsamples = args['nsamples']
        self.cutoffs = args['cutoffs']
        self.write_sfdp = args['write_sfdp']
        self.random = args['random']
        self.context_lines = args['context_lines']
                
args = Args({
    'input_text': os.path.join(data_dir, f'{filename}.txt'),
    'seed' : 0,
    'nsamples' : 14,
    'cutoffs' : '12 15 13',
    'write_sfdp': False,
    'random': False,
    'context_lines': 10
})

# %%
world = World(args)
world.generate(os.path.join(f"./outputs/{filename}.json"))
# Out:
# Current context: Long ago, twenty rings existed: three for elves, seven for dwarves, nine for men, and one made by the Dark Lord Sauron, in Mordor, which would rule all the others. Sauron poured all his evil and his will to dominate into this ring. An alliance of elves and humans resisted Sauron’s ring and fought against Mordor. They won the battle and the ring fell to Isildur, the son of the king of Gondor, but just as he was about to destroy the ring in Mount Doom, he changed his mind and held on to it for himself. Later he was killed, and the ring fell to the bottom of the sea. The creature Gollum discovered it and brought it to his cave. Then he lost it to the hobbit Bilbo Baggins. The movie cuts to an image of the hobbits’ peaceful Shire years later, where the wizard Gandalf has come to celebrate Bilbo’s 111th birthday. The party is an extravagant occasion with fireworks and revelry, and Bilbo entertains children with tales of his adventures. In the middle of a rambling speech, however, he puts on the ring, which makes him invisible, and runs to his house to pack his things and leave the Shire.
# -----	locations	-----
# >  the hobbits’ peaceful Shire 0.5356045203144902
# hobbits’ peaceful Shire
# >  his cave. 0.48713890927343245
# cave
# >  his house 0.927477886585716
# house
# >  the bottom of the sea. 0.6555059610437739
# bottom of the sea
# NO ANSWER FOUND
# --------------------
#
# -----	objects	-----
# >  the ring, 0.3511730248034059
# ring
# NO ANSWER FOUND
# --------------------
#
# -----	characters	-----
# >  Gandalf 0.5126977333840864
# Gandalf
# >  Bilbo Baggins. 0.8646303191104887
# Bilbo Baggins
# >  Bilbo’s 0.645515147322031
# Bilbo
# >  hobbits’ 0.3699838590933304
# hobbit
# >  wizard 0.5249797756975229
# wizard
# NO ANSWER FOUND
# --------------------
#
# -----	relations	-----
# Adding relation: ('Gandalf', 'located in', 'hobbits’ peaceful Shire')
# Adding relation: ('Gandalf', 'located in', 'cave')
# Found existing relation: Gandalf, located in, hobbits’ peaceful Shire
# Updating new relation: ('Gandalf', 'located in', 'cave')
# Adding relation: ('Gandalf', 'located in', 'house')
# Found existing relation: Gandalf, located in, hobbits’ peaceful Shire
# Updating new relation: ('Gandalf', 'located in', 'house')
# Found existing relation: Gandalf, located in, cave
# Updating new relation: ('Gandalf', 'located in', 'house')
# Adding relation: ('Gandalf', 'located in', 'bottom of the sea')
# Found existing relation: Gandalf, located in, hobbits’ peaceful Shire
# Updating new relation: ('Gandalf', 'located in', 'bottom of the sea')
# Found existing relation: Gandalf, located in, cave
# Updating new relation: ('Gandalf', 'located in', 'bottom of the sea')
# Found existing relation: Gandalf, located in, house
# Updating new relation: ('Gandalf', 'located in', 'bottom of the sea')
# Adding relation: ('Gandalf', 'has', 'ring')
# Adding relation: ('Gandalf', 'located in', 'hobbits’ peaceful Shire')
# Found existing relation: Gandalf, located in, hobbits’ peaceful Shire
# Found existing relation: Gandalf, located in, cave
# Updating new relation: ('Gandalf', 'located in', 'hobbits’ peaceful Shire')
# Found existing relation: Gandalf, located in, house
# Updating new relation: ('Gandalf', 'located in', 'hobbits’ peaceful Shire')
# Found existing relation: Gandalf, located in, bottom of the sea
# Updating new relation: ('Gandalf', 'located in', 'hobbits’ peaceful Shire')
# Adding relation: ('Bilbo Baggins', 'located in', 'hobbits’ peaceful Shire')
# Adding relation: ('Bilbo', 'located in', 'hobbits’ peaceful Shire')
# Adding relation: ('hobbit', 'located in', 'hobbits’ peaceful Shire')
# Adding relation: ('wizard', 'located in', 'hobbits’ peaceful Shire')
# --------------------
#
# Current context: Gandalf meets Bilbo back in his house and tells him he must give up the ring. Eventually Bilbo agrees to entrust it to his nephew Frodo. Gandalf senses that the ring is gaining power over Bilbo. We see a flash of Mordor, and hooded horsemen, the ringwraiths, leave its gates. The scene shifts to Gandalf, who rushes to a library to sift through ancient scrolls. As the ringwraiths begin to close in on Bilbo’s house, Gandalf returns to Frodo and throws the ring into Bilbo’s hearth. Mysterious letters appear on the ring’s surface. Only then does Gandalf realize that this ring is actually Sauron’s ring. Gandalf explains to Frodo that the ring and Sauron are one. He longs to find it, and it longs to find him.
# -----	locations	-----
# >  Bilbo’s hearth. 0.4921201195011785
# Bilbo’s hearth
# >  Bilbo’s house, 0.7014960067552438
# Bilbo’s house
# >  a library 0.7036514928366422
# library
# >  his house 0.3950736072178973
# house
# >  Gandalf, 0.3567799182331522
# Gandalf
# >  Frodo. 0.4292463636338046
# Frodo
# >  Bilbo 0.5051992456828364
# Bilbo
# >  ancient scrolls. 0.5558483706710584
# ancient scrolls
# >  Sauron’s 0.3783073022959435
# Sauron
# >  Mordor, 0.5333437620273788
# Mordor
# NO ANSWER FOUND
# --------------------
#
# -----	objects	-----
# >  the ring. 0.6959092932817357
# ring
# >  Bilbo’s hearth. 0.4990721225019433
# hearth
# >  ancient scrolls. 0.47006508105468076
# scrolls
# NO ANSWER FOUND
# --------------------
#
# -----	characters	-----
# >  Gandalf, 0.9731265423016409
# Gandalf
# >  Bilbo 0.3280715475473686
# Bilbo
# NO ANSWER FOUND
# --------------------
#
# -----	relations	-----
# Adding relation: ('ring', 'located in', 'Bilbo’s hearth')
# Adding relation: ('ring', 'located in', 'Bilbo’s house')
# Found existing relation: ring, located in, Bilbo’s hearth
# Updating new relation: ('ring', 'located in', 'Bilbo’s house')
# Adding relation: ('ring', 'located in', 'library')
# Found existing relation: ring, located in, Bilbo’s hearth
# Updating new relation: ('ring', 'located in', 'library')
# Found existing relation: ring, located in, Bilbo’s house
# Updating new relation: ('ring', 'located in', 'library')
# Adding relation: ('ring', 'located in', 'house')
# Found existing relation: ring, located in, Bilbo’s hearth
# Updating new relation: ('ring', 'located in', 'house')
# Found existing relation: ring, located in, Bilbo’s house
# Updating new relation: ('ring', 'located in', 'house')
# Found existing relation: ring, located in, library
# Updating new relation: ('ring', 'located in', 'house')
# Adding relation: ('ring', 'located in', 'Frodo')
# Found existing relation: ring, located in, Bilbo’s hearth
# Updating new relation: ('ring', 'located in', 'Frodo')
# Found existing relation: ring, located in, Bilbo’s house
# Updating new relation: ('ring', 'located in', 'Frodo')
# Found existing relation: ring, located in, library
# Updating new relation: ('ring', 'located in', 'Frodo')
# Found existing relation: ring, located in, house
# Updating new relation: ('ring', 'located in', 'Frodo')
# Adding relation: ('ring', 'located in', 'ancient scrolls')
# Found existing relation: ring, located in, Bilbo’s hearth
# Updating new relation: ('ring', 'located in', 'ancient scrolls')
# Found existing relation: ring, located in, Bilbo’s house
# Updating new relation: ('ring', 'located in', 'ancient scrolls')
# Found existing relation: ring, located in, library
# Updating new relation: ('ring', 'located in', 'ancient scrolls')
# Found existing relation: ring, located in, house
# Updating new relation: ('ring', 'located in', 'ancient scrolls')
# Found existing relation: ring, located in, Frodo
# Updating new relation: ('ring', 'located in', 'ancient scrolls')
# Adding relation: ('ring', 'located in', 'Sauron')
# Found existing relation: ring, located in, Bilbo’s hearth
# Updating new relation: ('ring', 'located in', 'Sauron')
# Found existing relation: ring, located in, Bilbo’s house
# Updating new relation: ('ring', 'located in', 'Sauron')
# Found existing relation: ring, located in, library
# Updating new relation: ('ring', 'located in', 'Sauron')
# Found existing relation: ring, located in, house
# Updating new relation: ('ring', 'located in', 'Sauron')
# Found existing relation: ring, located in, Frodo
# Updating new relation: ('ring', 'located in', 'Sauron')
# Found existing relation: ring, located in, ancient scrolls
# Updating new relation: ('ring', 'located in', 'Sauron')
# Adding relation: ('ring', 'located in', 'Mordor')
# Found existing relation: ring, located in, Bilbo’s hearth
# Updating new relation: ('ring', 'located in', 'Mordor')
# Found existing relation: ring, located in, Bilbo’s house
# Updating new relation: ('ring', 'located in', 'Mordor')
# Found existing relation: ring, located in, library
# Updating new relation: ('ring', 'located in', 'Mordor')
# Found existing relation: ring, located in, house
# Updating new relation: ('ring', 'located in', 'Mordor')
# Found existing relation: ring, located in, Frodo
# Updating new relation: ('ring', 'located in', 'Mordor')
# Found existing relation: ring, located in, ancient scrolls
# Updating new relation: ('ring', 'located in', 'Mordor')
# Found existing relation: ring, located in, Sauron
# Updating new relation: ('ring', 'located in', 'Mordor')
# --------------------
#
# Current context: Gandalf has learned that Sauron has kidnapped Gollum and that Gollum has revealed that Bilbo has the ring. The ring must leave the Shire or it will endanger all the hobbits. Gandalf cannot take it himself, since as a wizard he will wield too much power with the ring. He determines that Frodo must take it. Gandalf explains that if Frodo puts on the ring, it will draw Sauron’s agents to it. Suddenly, Gandalf discovers that Frodo’s friend Sam has been hiding outside and listening to Gandalf and Frodo. At first, Gandalf is furious at Sam’s eavesdropping, but then he recruits Sam to be Frodo’s travel partner and protector. Sam and Frodo leave Bilbo’s house, and in very little time they have ventured further from the Shire than ever before. Merry and Pippin, two mischievous hobbits who are fleeing a farmer from whom they’ve stolen, encounter Sam and Bilbo and join their party. The ringwraiths ride by, and the hobbits narrowly escape detection.
# -----	locations	-----
# >  the Shire 0.6493778370266262
# Shire
# >  Bilbo’s house, 0.9844127787401579
# Bilbo’s house
# >  Sam has been hiding outside 0.31390376975352297
# hiding outside
# NO ANSWER FOUND
# --------------------
#
# -----	objects	-----
# >  the ring. 0.5315591260429475
# ring
# NO ANSWER FOUND
# --------------------
#
# -----	characters	-----
# >  Frodo’s friend Sam 0.559384243662341
# Sam
# >  Frodo’s 0.41512991922940534
# Frodo’s
# >  Gandalf 0.24171507901215775
# Gandalf
# NO ANSWER FOUND
# --------------------
#
# -----	relations	-----
# Adding relation: ('Gandalf', 'located in', 'Shire')
# Found existing relation: Gandalf, located in, hobbits’ peaceful Shire
# Updating new relation: ('Gandalf', 'located in', 'Shire')
# Found existing relation: Gandalf, located in, cave
# Updating new relation: ('Gandalf', 'located in', 'Shire')
# Found existing relation: Gandalf, located in, house
# Updating new relation: ('Gandalf', 'located in', 'Shire')
# Found existing relation: Gandalf, located in, bottom of the sea
# Updating new relation: ('Gandalf', 'located in', 'Shire')
# Adding relation: ('Gandalf', 'located in', 'Bilbo’s house')
# Found existing relation: Gandalf, located in, hobbits’ peaceful Shire
# Updating new relation: ('Gandalf', 'located in', 'Bilbo’s house')
# Found existing relation: Gandalf, located in, cave
# Updating new relation: ('Gandalf', 'located in', 'Bilbo’s house')
# Found existing relation: Gandalf, located in, house
# Updating new relation: ('Gandalf', 'located in', 'Bilbo’s house')
# Found existing relation: Gandalf, located in, bottom of the sea
# Updating new relation: ('Gandalf', 'located in', 'Bilbo’s house')
# Found existing relation: Gandalf, located in, Shire
# Updating new relation: ('Gandalf', 'located in', 'Bilbo’s house')
# Adding relation: ('Sam', 'located in', 'hiding outside')
# Adding relation: ('Sam', 'has', 'ring')
# Found existing relation: Sam, has, Gandalf
# Updating new relation: ('Sam', 'has', 'ring')
# Adding relation: ('Sam', 'located in', 'hiding outside')
# Found existing relation: Sam, located in, hiding outside
# Adding relation: ('Frodo’s', 'located in', 'hiding outside')
# Adding relation: ('Gandalf', 'located in', 'hiding outside')
# Found existing relation: Gandalf, located in, hobbits’ peaceful Shire
# Updating new relation: ('Gandalf', 'located in', 'hiding outside')
# Found existing relation: Gandalf, located in, cave
# Updating new relation: ('Gandalf', 'located in', 'hiding outside')
# Found existing relation: Gandalf, located in, house
# Updating new relation: ('Gandalf', 'located in', 'hiding outside')
# Found existing relation: Gandalf, located in, bottom of the sea
# Updating new relation: ('Gandalf', 'located in', 'hiding outside')
# Found existing relation: Gandalf, located in, Shire
# Updating new relation: ('Gandalf', 'located in', 'hiding outside')
# Found existing relation: Gandalf, located in, Bilbo’s house
# Updating new relation: ('Gandalf', 'located in', 'hiding outside')
# --------------------
#
# Current context: Frodo is tempted to put on the ring, but Sam stops him. This urge is Frodo’s first insight into the power and temptation of the ring. The hobbits arrive at the town of Bree and enter the inn known as the Prancing Pony, where they are supposed to meet Gandalf, but the wizard isn’t there. The ring accidentally slips onto Frodo’s finger, alerting the ringwraiths to his whereabouts. A ranger named Strider introduces himself to the group of hobbits and urges them to be more careful. The wraiths arrive at the hotel, but the hobbits, thanks to Strider, are well hidden. Strider explains to them that the wraiths were formerly the nine human kings who had the nine human rings. They are hunting the ring because finding it is the only way they can come back to life. Meanwhile, Gandalf has approached another wizard, Saruman, for counsel. Saruman already knows about the ring and Sauron’s attempts to regain power.
# -----	locations	-----
# >  Bree 0.5085294088229463
# Bree
# >  the Prancing Pony, 0.4635169379119286
# Prancing Pony
# >  the town 0.3271788424034653
# town
# >  the inn 0.7773671172483481
# inn
# >  Gandalf, but the wizard isn’t there. 0.3673960915052622
# wizard isn’t there
# >  the hotel, 0.3051587850040472
# hotel
# >  ring accidentally slips onto Frodo’s finger, 0.35151436076579085
# ring
# >  Gandalf, 0.5699086798815517
# Gandalf
# >  Sam 0.8001770368362319
# Sam
# >  Frodo’s finger, 0.5244751617169314
# Frodo
# NO ANSWER FOUND
# --------------------
#
# -----	objects	-----
# >  Frodo’s finger, 0.5962887374066719
# Frodo’s finger
# NO ANSWER FOUND
# --------------------
#
# -----	characters	-----
# >  Gandalf, 0.9248144593340154
# Gandalf
# >  Sauron’s 0.4880370003952831
# Sauron’s
# >  Saruman, 0.3781201612803021
# Saruman
# NO ANSWER FOUND
# --------------------
#
# -----	relations	-----
# Adding relation: ('Prancing Pony', 'connected to', 'Bree')
# Adding relation: ('wizard isn’t there', 'connected to', 'Prancing Pony')
# Adding relation: ('wizard isn’t there', 'connected to', 'town')
# Adding relation: ('wizard isn’t there', 'connected to', 'inn')
# Adding relation: ('wizard isn’t there', 'connected to', 'wizard isn’t there')
# Adding relation: ('wizard isn’t there', 'connected to', 'hotel')
# Adding relation: ('wizard isn’t there', 'connected to', 'ring')
# Adding relation: ('Gandalf', 'located in', 'wizard isn’t there')
# Found existing relation: Gandalf, located in, hobbits’ peaceful Shire
# Updating new relation: ('Gandalf', 'located in', 'wizard isn’t there')
# Found existing relation: Gandalf, located in, cave
# Updating new relation: ('Gandalf', 'located in', 'wizard isn’t there')
# Found existing relation: Gandalf, located in, house
# Updating new relation: ('Gandalf', 'located in', 'wizard isn’t there')
# Found existing relation: Gandalf, located in, bottom of the sea
# Updating new relation: ('Gandalf', 'located in', 'wizard isn’t there')
# Found existing relation: Gandalf, located in, Shire
# Updating new relation: ('Gandalf', 'located in', 'wizard isn’t there')
# Found existing relation: Gandalf, located in, Bilbo’s house
# Updating new relation: ('Gandalf', 'located in', 'wizard isn’t there')
# Found existing relation: Gandalf, located in, hiding outside
# Updating new relation: ('Gandalf', 'located in', 'wizard isn’t there')
# Adding relation: ('wizard isn’t there', 'connected to', 'Sam')
# Adding relation: ('wizard isn’t there', 'connected to', 'Frodo')
# Adding relation: ('Frodo’s finger', 'located in', 'wizard isn’t there')
# Adding relation: ('Sauron’s', 'located in', 'wizard isn’t there')
# Adding relation: ('Saruman', 'located in', 'wizard isn’t there')
# --------------------
#
# Current context: He declares that Mordor cannot be defeated and that the two wizards must join with Sauron. Gandalf protests, and the wizards battle. Saruman wins and imprisons Gandalf atop Saruman’s giant tower in Isengard, called Orthanc. At his tower, Saruman is constructing a terrifying army with the intention of waging war on Middle-earth. A butterfly rouses Gandalf and takes a message from him, and a giant eagle comes and saves him. Strider and the hobbits head for Rivendell, home of the elves. They stop at a hill called Weathertop, where Strider hands the hobbits weapons and suggests they make camp for the night. The hobbits foolishly light a fire at their campsite, and the ringwraiths spot them. The ringwraiths stab Frodo, but Strider fights them off and saves Frodo’s life. Arwen, an elf princess, finds the party and hurries to Rivendell with Frodo, barely evading the wraiths.
# -----	locations	-----
# >  Rivendell, 0.7152693442531254
# Rivendell
# >  Weathertop, 0.7828103826344137
# Weathertop
# >  a hill 0.5096751295005686
# hill
# >  Orthanc. 0.34483489692565883
# Orthanc
# >  Middle-earth. 0.7452204738467088
# Middle-earth
# NO ANSWER FOUND
# --------------------
#
# -----	objects	-----
# NO ANSWER FOUND
# --------------------
#
# -----	characters	-----
# >  Arwen, an elf princess, 0.44188407351869813
# Arwen
# >  an elf princess, 0.8767441250908493
# elf princess
# NO ANSWER FOUND
# --------------------
#
# -----	relations	-----
# Adding relation: ('elf princess', 'located in', 'Rivendell')
# Adding relation: ('elf princess', 'located in', 'Weathertop')
# Found existing relation: elf princess, located in, Rivendell
# Updating new relation: ('elf princess', 'located in', 'Weathertop')
# Adding relation: ('elf princess', 'located in', 'hill')
# Found existing relation: elf princess, located in, Rivendell
# Updating new relation: ('elf princess', 'located in', 'hill')
# Found existing relation: elf princess, located in, Weathertop
# Updating new relation: ('elf princess', 'located in', 'hill')
# Adding relation: ('elf princess', 'located in', 'Orthanc')
# Found existing relation: elf princess, located in, Rivendell
# Updating new relation: ('elf princess', 'located in', 'Orthanc')
# Found existing relation: elf princess, located in, Weathertop
# Updating new relation: ('elf princess', 'located in', 'Orthanc')
# Found existing relation: elf princess, located in, hill
# Updating new relation: ('elf princess', 'located in', 'Orthanc')
# Adding relation: ('elf princess', 'located in', 'Middle-earth')
# Found existing relation: elf princess, located in, Rivendell
# Updating new relation: ('elf princess', 'located in', 'Middle-earth')
# Found existing relation: elf princess, located in, Weathertop
# Updating new relation: ('elf princess', 'located in', 'Middle-earth')
# Found existing relation: elf princess, located in, hill
# Updating new relation: ('elf princess', 'located in', 'Middle-earth')
# Found existing relation: elf princess, located in, Orthanc
# Updating new relation: ('elf princess', 'located in', 'Middle-earth')
# --------------------
#
# Current context: Frodo is cured and wakes up to discover Gandalf by his side. Bilbo, who has aged significantly, is also at Rivendell, having just completed the book of his adventures, There and Back Again: A Hobbit’s Tale. Elrond, the king of the elves and Arwen’s father, tells Gandalf that the ring cannot stay in Rivendell but must go further. Pessimistic about the future of Middle-earth, Elrond claims that the time of the elves is over, the dwarves are too selfish to help, and men are weak. The ring survives because of Isildur’s weakness. Moreover, the line of human kings is broken, though the heir of Gondor, who has chosen exile, can reunite them. Shortly after this declaration, we learn that Strider’s true name is Aragorn and that he is the heir of Gondor. We also learn that Aragorn and Arwen are in love and have been for many years. However, this love requires that Arwen sacrifice her immortality, one of the chief attributes of elves. Elrond convenes a meeting and announces that the races must come together to defeat Mordor.
# -----	locations	-----
# >  Rivendell, 0.8927620031456692
# Rivendell
# >  Gandalf by his side. 0.639634759670277
# Gandalf
# >  Hobbit’s Tale. 0.3458803422332921
# Hobbit’s Tale
# >  Bilbo, 0.7928695926293928
# Bilbo
# NO ANSWER FOUND
# --------------------
#
# -----	objects	-----
# >  the ring 0.720621558958089
# ring
# NO ANSWER FOUND
# --------------------
#
# -----	characters	-----
# >  Gandalf 0.6214568321861795
# Gandalf
# >  Bilbo, 0.9810736741532605
# Bilbo
# NO ANSWER FOUND
# --------------------
#
# -----	relations	-----
# Adding relation: ('ring', 'located in', 'Rivendell')
# Found existing relation: ring, located in, Bilbo’s hearth
# Updating new relation: ('ring', 'located in', 'Rivendell')
# Found existing relation: ring, located in, Bilbo’s house
# Updating new relation: ('ring', 'located in', 'Rivendell')
# Found existing relation: ring, located in, library
# Updating new relation: ('ring', 'located in', 'Rivendell')
# Found existing relation: ring, located in, house
# Updating new relation: ('ring', 'located in', 'Rivendell')
# Found existing relation: ring, located in, Frodo
# Updating new relation: ('ring', 'located in', 'Rivendell')
# Found existing relation: ring, located in, ancient scrolls
# Updating new relation: ('ring', 'located in', 'Rivendell')
# Found existing relation: ring, located in, Sauron
# Updating new relation: ('ring', 'located in', 'Rivendell')
# Found existing relation: ring, located in, Mordor
# Updating new relation: ('ring', 'located in', 'Rivendell')
# Adding relation: ('ring', 'located in', 'Hobbit’s Tale')
# Found existing relation: ring, located in, Bilbo’s hearth
# Updating new relation: ('ring', 'located in', 'Hobbit’s Tale')
# Found existing relation: ring, located in, Bilbo’s house
# Updating new relation: ('ring', 'located in', 'Hobbit’s Tale')
# Found existing relation: ring, located in, library
# Updating new relation: ('ring', 'located in', 'Hobbit’s Tale')
# Found existing relation: ring, located in, house
# Updating new relation: ('ring', 'located in', 'Hobbit’s Tale')
# Found existing relation: ring, located in, Frodo
# Updating new relation: ('ring', 'located in', 'Hobbit’s Tale')
# Found existing relation: ring, located in, ancient scrolls
# Updating new relation: ('ring', 'located in', 'Hobbit’s Tale')
# Found existing relation: ring, located in, Sauron
# Updating new relation: ('ring', 'located in', 'Hobbit’s Tale')
# Found existing relation: ring, located in, Mordor
# Updating new relation: ('ring', 'located in', 'Hobbit’s Tale')
# Found existing relation: ring, located in, Rivendell
# Updating new relation: ('ring', 'located in', 'Hobbit’s Tale')
# --------------------
#
# Current context: Frodo presents the ring, and Elrond insists that it must be destroyed in the fires of Mount Doom, where it was made. There is some disagreement as to who will undertake this arduous task, and eventually Frodo emerges. Others step forward to accompany Frodo, forming a fellowship of the ring. The fellowship includes the hobbits Frodo, Sam, Merry, and Pippin; one elf, Legolas; one dwarf, Gimli; one wizard, Gandalf; and two humans, Aragorn and Boromir. Boromir is the son of the steward of Gondor, who has ruled the kingdom in the absence of the rightful king. The fellowship sets forth from Rivendell. Saruman causes an avalanche of snow to block the group’s attempt to cross the pass of Caradhras, and they decide to enter the realm of the dwarves, the mines of Moria. Inside Moria, the party discovers that all the dwarves have been killed, and soon the fellowship is surrounded by an army of orcs, inhuman creatures that are also brutal, ruthless warriors. The orcs disperse, however, at the approach of a Balrog, a demonic creature from the underworld. The fellowship flees this creature as the mines collapse.
# -----	locations	-----
# >  Rivendell. 0.9731230302847438
# Rivendell
# >  Moria. 0.3904105946505491
# Moria
# >  the pass of Caradhras, 0.2840018303899299
# Caradhras
# >  the realm of the dwarves, 0.5148312748287877
# dwarves
# >  snow 0.41384366227480324
# snow
# >  the realm 0.4802705962484436
# realm
# >  Mount Doom, 0.2432708801867429
# Mount Doom
# >  mines 0.45591508054663965
# mines
# >  underworld. 0.43252234846663357
# underworld
# >  the pass 0.34340801155277795
# pass
# >  fires 0.5048208949283587
# fires
# >  ring. 1.0
# ring
# NO ANSWER FOUND
# --------------------
#
# -----	objects	-----
# >  the ring, 0.8744392163737368
# ring
# NO ANSWER FOUND
# --------------------
#
# -----	characters	-----
# >  hobbits Frodo, Sam, Merry, and Pippin; 0.35282998326188103
# hobbits
# >  Frodo 0.6418551483903318
# Frodo
# NO ANSWER FOUND
# --------------------
#
# -----	relations	-----
# Adding relation: ('pass', 'connected to', 'Rivendell')
# Adding relation: ('pass', 'connected to', 'Moria')
# Adding relation: ('pass', 'connected to', 'Caradhras')
# Adding relation: ('pass', 'connected to', 'dwarves')
# Adding relation: ('pass', 'connected to', 'snow')
# Adding relation: ('pass', 'connected to', 'realm')
# Adding relation: ('Frodo', 'located in', 'Mount Doom')
# Found existing relation: Frodo, located in, ring
# Updating new relation: ('Frodo', 'located in', 'Mount Doom')
# Adding relation: ('Frodo', 'located in', 'mines')
# Found existing relation: Frodo, located in, ring
# Updating new relation: ('Frodo', 'located in', 'mines')
# Found existing relation: Frodo, located in, Mount Doom
# Updating new relation: ('Frodo', 'located in', 'mines')
# Adding relation: ('Frodo', 'located in', 'underworld')
# Found existing relation: Frodo, located in, ring
# Updating new relation: ('Frodo', 'located in', 'underworld')
# Found existing relation: Frodo, located in, Mount Doom
# Updating new relation: ('Frodo', 'located in', 'underworld')
# Found existing relation: Frodo, located in, mines
# Updating new relation: ('Frodo', 'located in', 'underworld')
# Adding relation: ('Frodo', 'located in', 'pass')
# Found existing relation: Frodo, located in, ring
# Updating new relation: ('Frodo', 'located in', 'pass')
# Found existing relation: Frodo, located in, Mount Doom
# Updating new relation: ('Frodo', 'located in', 'pass')
# Found existing relation: Frodo, located in, mines
# Updating new relation: ('Frodo', 'located in', 'pass')
# Found existing relation: Frodo, located in, underworld
# Updating new relation: ('Frodo', 'located in', 'pass')
# Adding relation: ('Frodo', 'located in', 'fires')
# Found existing relation: Frodo, located in, ring
# Updating new relation: ('Frodo', 'located in', 'fires')
# Found existing relation: Frodo, located in, Mount Doom
# Updating new relation: ('Frodo', 'located in', 'fires')
# Found existing relation: Frodo, located in, mines
# Updating new relation: ('Frodo', 'located in', 'fires')
# Found existing relation: Frodo, located in, underworld
# Updating new relation: ('Frodo', 'located in', 'fires')
# Found existing relation: Frodo, located in, pass
# Updating new relation: ('Frodo', 'located in', 'fires')
# Adding relation: ('Frodo', 'has', 'ring')
# Found existing relation: Frodo, has, Gandalf
# Updating new relation: ('Frodo', 'has', 'ring')
# Found existing relation: Frodo, has, Sam
# Updating new relation: ('Frodo', 'has', 'ring')
# Adding relation: ('Frodo', 'located in', 'Mount Doom')
# Found existing relation: Frodo, located in, Mount Doom
# Found existing relation: Frodo, located in, mines
# Updating new relation: ('Frodo', 'located in', 'Mount Doom')
# Found existing relation: Frodo, located in, underworld
# Updating new relation: ('Frodo', 'located in', 'Mount Doom')
# Found existing relation: Frodo, located in, pass
# Updating new relation: ('Frodo', 'located in', 'Mount Doom')
# Found existing relation: Frodo, located in, fires
# Updating new relation: ('Frodo', 'located in', 'Mount Doom')
# --------------------
#
# Current context: Gandalf stays behind to battle the Balrog, which he sends collapsing to the depths of the mines. However, as the Balrog falls, it grabs hold of Gandalf’s legs and drags the wizard down with it. The fellowship emerges from the mines saddened by the loss of Gandalf, but Aragorn insists they have no time to mourn and must press on. Coming to a forest, the Sylvan elves, led by Galadriel, the Lady of Woods, meet the fellowship. That evening, the Lady and Frodo speak in private. She asks him to look into a mirror, which is a basin of water, and tell her what he sees. He sees visions of the Shire destroyed, of his companions surrounded by orcs, and of the huge, fiery eye of Sauron. The Lady tells him he has seen visions of what will happen if his mission fails. She warns him that the fellowship is breaking and that one by one the ring will destroy them all. Frodo doubts his ability to accomplish his task on his own, but she says that as the ring-bearer, he is already alone.
# -----	locations	-----
# >  a forest, 0.8484483870616264
# forest
# >  mines. 0.34051822091462663
# mines
# NO ANSWER FOUND
# --------------------
#
# -----	objects	-----
# >  a mirror, 0.4991925118001281
# mirror
# >  basin of water, 0.6221210449860026
# basin of water
# >  ring 0.7746151761167362
# ring
# >  forest, 0.5880637987364443
# forest
# NO ANSWER FOUND
# --------------------
#
# -----	characters	-----
# >  Gandalf 0.6679475475391249
# Gandalf
# >  Frodo 0.9366842062454724
# Frodo
# >  Aragorn 0.9596077966406431
# Aragorn
# NO ANSWER FOUND
# --------------------
#
# -----	relations	-----
# Adding relation: ('Gandalf', 'located in', 'mines')
# Found existing relation: Gandalf, located in, hobbits’ peaceful Shire
# Updating new relation: ('Gandalf', 'located in', 'mines')
# Found existing relation: Gandalf, located in, cave
# Updating new relation: ('Gandalf', 'located in', 'mines')
# Found existing relation: Gandalf, located in, house
# Updating new relation: ('Gandalf', 'located in', 'mines')
# Found existing relation: Gandalf, located in, bottom of the sea
# Updating new relation: ('Gandalf', 'located in', 'mines')
# Found existing relation: Gandalf, located in, Shire
# Updating new relation: ('Gandalf', 'located in', 'mines')
# Found existing relation: Gandalf, located in, Bilbo’s house
# Updating new relation: ('Gandalf', 'located in', 'mines')
# Found existing relation: Gandalf, located in, hiding outside
# Updating new relation: ('Gandalf', 'located in', 'mines')
# Found existing relation: Gandalf, located in, wizard isn’t there
# Updating new relation: ('Gandalf', 'located in', 'mines')
# Adding relation: ('Frodo', 'has', 'mirror')
# Adding relation: ('Frodo', 'has', 'basin of water')
# Adding relation: ('Frodo', 'has', 'ring')
# Found existing relation: Frodo, has, Gandalf
# Updating new relation: ('Frodo', 'has', 'ring')
# Found existing relation: Frodo, has, Frodo
# Updating new relation: ('Frodo', 'has', 'ring')
# Found existing relation: Frodo, has, Sam
# Updating new relation: ('Frodo', 'has', 'ring')
# --------------------
#
# Current context: If he does not accomplish the task, no one will. The Lady encourages Frodo and gives him a parting gift, a star of light that will illuminate his path when all other lights go out. The next day, the fellowship departs in boats down the river. Meanwhile, Saruman has dispatched Uruk-hai, unusually large and powerful creatures whose sole mission is to destroy the world of men, after the party, with the instructions to kill everyone but bring the hobbits back alive. After docking on dry land, Frodo wanders off, and Boromir follows. Frodo is determined to go off alone, but Boromir wants the ring. He is about to attack Frodo for it when Frodo puts on the ring and disappears. This is the longest period of time that Frodo has ever worn the ring, and he has his longest look yet at the fiery eye of Sauron. When Frodo takes the ring off, Aragorn is beside him. Frodo distrusts him, too, but Aragorn passes the test that Boromir failed.
# -----	locations	-----
# >  dry land, 0.44266775959252685
# dry land
# >  Frodo wanders off, 0.6265270391836698
# Frodo wanders off
# >  Saruman has dispatched Uruk-hai, 0.34563985764338173
# Uruk-hai
# >  Boromir 0.33903935789095824
# Boromir
# >  the river. 0.6695218185596272
# river
# NO ANSWER FOUND
# --------------------
#
# -----	objects	-----
# >  a star of light 0.3978128782996049
# star of light
# NO ANSWER FOUND
# --------------------
#
# -----	characters	-----
# >  Boromir 0.3400411702401582
# Boromir
# >  Frodo 0.7318871793809318
# Frodo
# NO ANSWER FOUND
# --------------------
#
# -----	relations	-----
# Adding relation: ('Frodo', 'located in', 'dry land')
# Found existing relation: Frodo, located in, Mount Doom
# Updating new relation: ('Frodo', 'located in', 'dry land')
# Found existing relation: Frodo, located in, mines
# Updating new relation: ('Frodo', 'located in', 'dry land')
# Found existing relation: Frodo, located in, underworld
# Updating new relation: ('Frodo', 'located in', 'dry land')
# Found existing relation: Frodo, located in, pass
# Updating new relation: ('Frodo', 'located in', 'dry land')
# Found existing relation: Frodo, located in, fires
# Updating new relation: ('Frodo', 'located in', 'dry land')
# Adding relation: ('Boromir', 'located in', 'Frodo wanders off')
# Adding relation: ('Boromir', 'located in', 'Uruk-hai')
# Found existing relation: Boromir, located in, Frodo wanders off
# Updating new relation: ('Boromir', 'located in', 'Uruk-hai')
# Adding relation: ('Boromir', 'located in', 'Frodo wanders off')
# Found existing relation: Boromir, located in, Frodo wanders off
# Found existing relation: Boromir, located in, Uruk-hai
# Updating new relation: ('Boromir', 'located in', 'Frodo wanders off')
# Adding relation: ('Frodo wanders off', 'connected to', 'river')
# Adding relation: ('star of light', 'located in', 'Frodo wanders off')
# Adding relation: ('Frodo', 'located in', 'Frodo wanders off')
# Found existing relation: Frodo, located in, Mount Doom
# Updating new relation: ('Frodo', 'located in', 'Frodo wanders off')
# Found existing relation: Frodo, located in, mines
# Updating new relation: ('Frodo', 'located in', 'Frodo wanders off')
# Found existing relation: Frodo, located in, underworld
# Updating new relation: ('Frodo', 'located in', 'Frodo wanders off')
# Found existing relation: Frodo, located in, pass
# Updating new relation: ('Frodo', 'located in', 'Frodo wanders off')
# Found existing relation: Frodo, located in, fires
# Updating new relation: ('Frodo', 'located in', 'Frodo wanders off')
# Found existing relation: Frodo, located in, dry land
# Updating new relation: ('Frodo', 'located in', 'Frodo wanders off')
# --------------------
#
# Current context: He tells Frodo to run off and turns to face the approaching army of Uruk-hai. Boromir also fights valiantly but is badly wounded. The Uruk-hai capture Pippin and Merry. Aragorn wins an epic battle with an Uruk-hai, then rushes to the fallen Boromir, who confesses that he tried to steal the ring from Frodo. Boromir says he has failed the group, but Aragorn tells Boromir he has fought bravely. Boromir swears allegiance to Aragorn, his rightful king, as he dies. Back at the river, Frodo regrets having the ring but remembers Gandalf’s words about his destiny. He departs in a boat, but Sam insists on coming along. Though he can’t swim, Sam jumps in the water, and Frodo is forced to rescue his flailing friend and pull him aboard. Once safe, Sam reminds Frodo that he made a promise never to leave him.
# -----	locations	-----
# >  the river, 0.8702978058107391
# river
# NO ANSWER FOUND
# --------------------
#
# -----	objects	-----
# NO ANSWER FOUND
# --------------------
#
# -----	characters	-----
# >  Sam 0.6272227439048087
# Sam
# >  Gandalf’s 0.625632739489782
# Gandalf’s
# NO ANSWER FOUND
# --------------------
#
# -----	relations	-----
# Adding relation: ('Sam', 'located in', 'river')
# Found existing relation: Sam, located in, hiding outside
# Updating new relation: ('Sam', 'located in', 'river')
# Adding relation: ('Sam', 'located in', 'river')
# Found existing relation: Sam, located in, hiding outside
# Updating new relation: ('Sam', 'located in', 'river')
# Found existing relation: Sam, located in, river
# Adding relation: ('Gandalf’s', 'located in', 'river')
# --------------------
#
# Current context: On the water’s opposite side, Sam and Frodo climb a mountain and spot Mordor in the distance.
# -----	locations	-----
# >  distance. 0.18259676792692062
# distance
# >  a mountain 0.4340706703369446
# mountain
# >  the water’s opposite side, 0.36561861138389545
# water’s opposite side
# >  Mordor 0.24401054846902512
# Mordor
# >  Sam and Frodo 1.0
# Sam and Frodo
# NO ANSWER FOUND
# --------------------
#
# -----	objects	-----
# >  a mountain 0.4146560232239403
# mountain
# NO ANSWER FOUND
# --------------------
#
# -----	characters	-----
# >  Mordor 0.9893249786133198
# Mordor
# >  Sam and Frodo 0.5341699258296537
# Sam
# >  Frodo 0.9960276073471217
# Frodo
# NO ANSWER FOUND
# --------------------
#
# -----	relations	-----
# Adding relation: ('Mordor', 'located in', 'distance')
# Found existing relation: Mordor, located in, ring
# Updating new relation: ('Mordor', 'located in', 'distance')
# Adding relation: ('mountain', 'located in', 'water’s opposite side')
# Adding relation: ('water’s opposite side', 'connected to', 'water’s opposite side')
# Adding relation: ('Mordor', 'located in', 'water’s opposite side')
# Found existing relation: Mordor, located in, ring
# Updating new relation: ('Mordor', 'located in', 'water’s opposite side')
# Found existing relation: Mordor, located in, distance
# Updating new relation: ('Mordor', 'located in', 'water’s opposite side')
# Adding relation: ('water’s opposite side', 'connected to', 'Sam and Frodo')
# Adding relation: ('Sam', 'located in', 'water’s opposite side')
# Found existing relation: Sam, located in, hiding outside
# Updating new relation: ('Sam', 'located in', 'water’s opposite side')
# Found existing relation: Sam, located in, river
# Updating new relation: ('Sam', 'located in', 'water’s opposite side')
# Adding relation: ('Frodo', 'located in', 'water’s opposite side')
# Found existing relation: Frodo, located in, Mount Doom
# Updating new relation: ('Frodo', 'located in', 'water’s opposite side')
# Found existing relation: Frodo, located in, mines
# Updating new relation: ('Frodo', 'located in', 'water’s opposite side')
# Found existing relation: Frodo, located in, underworld
# Updating new relation: ('Frodo', 'located in', 'water’s opposite side')
# Found existing relation: Frodo, located in, pass
# Updating new relation: ('Frodo', 'located in', 'water’s opposite side')
# Found existing relation: Frodo, located in, fires
# Updating new relation: ('Frodo', 'located in', 'water’s opposite side')
# Found existing relation: Frodo, located in, dry land
# Updating new relation: ('Frodo', 'located in', 'water’s opposite side')
# Found existing relation: Frodo, located in, Frodo wanders off
# Updating new relation: ('Frodo', 'located in', 'water’s opposite side')
# --------------------

# %%
for n in world.graph.nodes:
    print(f'"{n}" is {world.graph.nodes[n]["type"]}')
    for a in world.graph.adj[n]:
    	print(f'\t {world.graph.adj[n][a]["label"]} "{a}"')
# Out:
# "hobbits’ peaceful Shire" is location
# 	 located in "Gandalf"
# 	 located in "Bilbo Baggins"
# 	 located in "Bilbo"
# 	 located in "hobbit"
# 	 located in "wizard"
# "Gandalf" is character
# 	 located in "hobbits’ peaceful Shire"
# 	 located in "cave"
# 	 located in "house"
# 	 located in "bottom of the sea"
# 	 has "ring"
# 	 located in "Shire"
# 	 located in "Bilbo’s house"
# 	 located in "hiding outside"
# 	 located in "wizard isn’t there"
# 	 located in "mines"
# "cave" is location
# 	 located in "Gandalf"
# "house" is location
# 	 located in "Gandalf"
# 	 located in "ring"
# "bottom of the sea" is location
# 	 located in "Gandalf"
# "ring" is object
# 	 has "Gandalf"
# 	 located in "Bilbo’s hearth"
# 	 located in "Bilbo’s house"
# 	 located in "library"
# 	 located in "house"
# 	 has "Frodo"
# 	 located in "ancient scrolls"
# 	 located in "Sauron"
# 	 located in "Mordor"
# 	 has "Sam"
# 	 connected to "wizard isn’t there"
# 	 located in "Rivendell"
# 	 located in "Hobbit’s Tale"
# "Bilbo Baggins" is character
# 	 located in "hobbits’ peaceful Shire"
# "Bilbo" is character
# 	 located in "hobbits’ peaceful Shire"
# "hobbit" is character
# 	 located in "hobbits’ peaceful Shire"
# "wizard" is character
# 	 located in "hobbits’ peaceful Shire"
# "Bilbo’s hearth" is location
# 	 located in "ring"
# "Bilbo’s house" is location
# 	 located in "ring"
# 	 located in "Gandalf"
# "library" is location
# 	 located in "ring"
# "Frodo" is location
# 	 has "ring"
# 	 connected to "wizard isn’t there"
# 	 located in "Mount Doom"
# 	 located in "mines"
# 	 located in "underworld"
# 	 located in "pass"
# 	 located in "fires"
# 	 has "mirror"
# 	 has "basin of water"
# 	 located in "dry land"
# 	 located in "Frodo wanders off"
# 	 located in "water’s opposite side"
# "ancient scrolls" is location
# 	 located in "ring"
# "Sauron" is location
# 	 located in "ring"
# "Mordor" is location
# 	 located in "ring"
# 	 located in "distance"
# 	 located in "water’s opposite side"
# "hearth" is object
# "scrolls" is object
# "Shire" is location
# 	 located in "Gandalf"
# "hiding outside" is location
# 	 located in "Sam"
# 	 located in "Frodo’s"
# 	 located in "Gandalf"
# "Sam" is character
# 	 located in "hiding outside"
# 	 has "ring"
# 	 connected to "wizard isn’t there"
# 	 located in "river"
# 	 located in "water’s opposite side"
# "Frodo’s" is character
# 	 located in "hiding outside"
# "Bree" is location
# 	 connected to "Prancing Pony"
# "Prancing Pony" is location
# 	 connected to "Bree"
# 	 connected to "wizard isn’t there"
# "wizard isn’t there" is location
# 	 connected to "Prancing Pony"
# 	 connected to "town"
# 	 connected to "inn"
# 	 connected to "wizard isn’t there"
# 	 connected to "hotel"
# 	 connected to "ring"
# 	 located in "Gandalf"
# 	 connected to "Sam"
# 	 connected to "Frodo"
# 	 located in "Frodo’s finger"
# 	 located in "Sauron’s"
# 	 located in "Saruman"
# "town" is location
# 	 connected to "wizard isn’t there"
# "inn" is location
# 	 connected to "wizard isn’t there"
# "hotel" is location
# 	 connected to "wizard isn’t there"
# "Frodo’s finger" is object
# 	 located in "wizard isn’t there"
# "Sauron’s" is character
# 	 located in "wizard isn’t there"
# "Saruman" is character
# 	 located in "wizard isn’t there"
# "Rivendell" is location
# 	 located in "elf princess"
# 	 located in "ring"
# 	 connected to "pass"
# "elf princess" is character
# 	 located in "Rivendell"
# 	 located in "Weathertop"
# 	 located in "hill"
# 	 located in "Orthanc"
# 	 located in "Middle-earth"
# "Weathertop" is location
# 	 located in "elf princess"
# "hill" is location
# 	 located in "elf princess"
# "Orthanc" is location
# 	 located in "elf princess"
# "Middle-earth" is location
# 	 located in "elf princess"
# "Arwen" is character
# "Hobbit’s Tale" is location
# 	 located in "ring"
# "pass" is location
# 	 connected to "Rivendell"
# 	 connected to "Moria"
# 	 connected to "Caradhras"
# 	 connected to "dwarves"
# 	 connected to "snow"
# 	 connected to "realm"
# 	 located in "Frodo"
# "Moria" is location
# 	 connected to "pass"
# "Caradhras" is location
# 	 connected to "pass"
# "dwarves" is location
# 	 connected to "pass"
# "snow" is location
# 	 connected to "pass"
# "realm" is location
# 	 connected to "pass"
# "Mount Doom" is location
# 	 located in "Frodo"
# "mines" is location
# 	 located in "Frodo"
# 	 located in "Gandalf"
# "underworld" is location
# 	 located in "Frodo"
# "fires" is location
# 	 located in "Frodo"
# "hobbits" is character
# "mirror" is object
# 	 has "Frodo"
# "basin of water" is object
# 	 has "Frodo"
# "Aragorn" is character
# "dry land" is location
# 	 located in "Frodo"
# "Frodo wanders off" is location
# 	 located in "Boromir"
# 	 connected to "river"
# 	 located in "star of light"
# 	 located in "Frodo"
# "Boromir" is character
# 	 located in "Frodo wanders off"
# 	 located in "Uruk-hai"
# "Uruk-hai" is location
# 	 located in "Boromir"
# "river" is location
# 	 connected to "Frodo wanders off"
# 	 located in "Sam"
# 	 located in "Gandalf’s"
# "star of light" is object
# 	 located in "Frodo wanders off"
# "Gandalf’s" is character
# 	 located in "river"
# "distance" is location
# 	 located in "Mordor"
# "mountain" is object
# 	 located in "water’s opposite side"
# "water’s opposite side" is location
# 	 located in "mountain"
# 	 connected to "water’s opposite side"
# 	 located in "Mordor"
# 	 connected to "Sam and Frodo"
# 	 located in "Sam"
# 	 located in "Frodo"
# "Sam and Frodo" is location
# 	 connected to "water’s opposite side"

# %%
g = nx.Graph()
g.add_node('a')
g.add_node('b')
g.add_node('c', type='gg')
g.add_edge('a','b', type='conn')
g.add_edge('a','c', type='conn')

# %%
world.graph.nodes['bottom of the sea']
# Out:
# {'type': 'location'}
