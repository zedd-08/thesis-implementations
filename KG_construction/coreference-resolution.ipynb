# %% [markdown]
# # Co-reference Resolution for input text
#
# Coreference resolution is the task of finding (and replacing) all expressions that refer to the same entity in a text. There are two well know methods to do this in python: SpaCy's NeuralCoref and AllenNLP's Coreference Resolution.

# %% [markdown]
# ## Using Spacy - neuralcoref

# %%
# %python -m spacy download en_core_web_sm

# %%
import spacy
import neuralcoref

nlp = spacy.load('en_core_web_sm')  # load the model
neuralcoref.add_to_pipe(nlp)

text = "Joseph Robinette Biden Jr. is an American politician who is the 46th and\
current president of the United States. A member of the Democratic Party, \
he served as the 47th vice president from 2009 to 2017 under Barack Obama and\
represented Delaware in the United States Senate from 1973 to 2009."

doc = nlp(doc)  # get the spaCy Doc (composed of Tokens)

print(doc._.coref_clusters)  # You can see cluster of similar mentions

# %%
print(doc._.coref_resolved)

# %% [markdown]
# ## Using AllenNLP - allennlp-models

# %%
# %pip install allennlp allennlp-models
# Out:
# Collecting allennlp
#   Using cached allennlp-2.10.1-py3-none-any.whl (730 kB)
# Collecting allennlp-models
#   Using cached allennlp_models-2.10.1-py3-none-any.whl (464 kB)
# Requirement already satisfied: nltk>=3.6.5 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from allennlp) (3.8.1)
# Collecting torch<1.13.0,>=1.10.0
#   Downloading torch-1.12.1-cp37-cp37m-manylinux1_x86_64.whl (776.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 3.5 MB/s eta 0:00:0000:0100:04
# Requirement already satisfied: traitlets>5.1.1 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from allennlp) (5.7.1)
# Collecting base58>=2.1.1
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting scipy>=1.7.3
#   Using cached scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
# Requirement already satisfied: sentencepiece>=0.1.96 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from allennlp) (0.1.99)
# Collecting dill>=0.3.4
#   Using cached dill-0.3.6-py3-none-any.whl (110 kB)
# Requirement already satisfied: termcolor==1.1.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from allennlp) (1.1.0)
# Requirement already satisfied: tensorboardX>=1.2 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from allennlp) (2.4)
# Collecting lmdb>=1.2.1
#   Downloading lmdb-1.4.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.4/294.4 kB 8.3 MB/s eta 0:00:00a 0:00:01
# Collecting transformers<4.21,>=4.1
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 8.2 MB/s eta 0:00:00a 0:00:01m
# Collecting numpy>=1.21.4
#   Using cached numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Collecting filelock<3.8,>=3.3
#   Downloading filelock-3.7.1-py3-none-any.whl (10 kB)
# Collecting cached-path<1.2.0,>=1.1.3
#   Downloading cached_path-1.1.6-py3-none-any.whl (26 kB)
# Collecting protobuf<4.0.0,>=3.12.0
#   Using cached protobuf-3.20.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting wandb<0.13.0,>=0.10.0
#   Downloading wandb-0.12.21-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: spacy<3.4,>=2.1.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from allennlp) (2.1.0)
# Collecting typer>=0.4.1
#   Using cached typer-0.9.0-py3-none-any.whl (45 kB)
# Collecting h5py>=3.6.0
#   Downloading h5py-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 8.2 MB/s eta 0:00:00a 0:00:01
# Collecting more-itertools>=8.12.0
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: torchvision<0.14.0,>=0.8.1 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from allennlp) (0.8.2)
# Requirement already satisfied: scikit-learn>=1.0.1 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from allennlp) (1.0.2)
# Collecting huggingface-hub>=0.0.16
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 6.3 MB/s eta 0:00:0000:01
# Collecting jsonnet>=0.10.0
#   Downloading jsonnet-0.20.0.tar.gz (594 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.2/594.2 kB 7.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.28 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from allennlp) (2.31.0)
# Collecting fairscale==0.4.6
#   Downloading fairscale-0.4.6.tar.gz (248 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.2/248.2 kB 8.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: sacremoses in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from allennlp) (0.0.53)
# Collecting pytest>=6.2.5
#   Downloading pytest-7.4.0-py3-none-any.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 8.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tqdm>=4.62 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from allennlp) (4.65.0)
# Collecting conllu==4.4.2
#   Downloading conllu-4.4.2-py2.py3-none-any.whl (15 kB)
# Collecting word2number>=1.1
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting py-rouge==1.1
#   Downloading py_rouge-1.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 8.0 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.13.1-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 7.2 MB/s eta 0:00:00a 0:00:01
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.5 MB/s eta 0:00:00
# Collecting rich<13.0,>=12.1
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 kB 8.3 MB/s eta 0:00:00
# Collecting google-cloud-storage<3.0,>=1.32.0
#   Downloading google_cloud_storage-2.10.0-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 9.1 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.0.16
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: boto3<2.0,>=1.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from cached-path<1.2.0,>=1.1.3->allennlp) (1.26.160)
# Requirement already satisfied: packaging>=20.9 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from huggingface-hub>=0.0.16->allennlp) (23.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from huggingface-hub>=0.0.16->allennlp) (4.3.0)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
# Requirement already satisfied: importlib-metadata in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from huggingface-hub>=0.0.16->allennlp) (6.7.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from nltk>=3.6.5->allennlp) (2023.6.3)
# Requirement already satisfied: joblib in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from nltk>=3.6.5->allennlp) (1.2.0)
# Requirement already satisfied: click in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from nltk>=3.6.5->allennlp) (8.1.3)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from pytest>=6.2.5->allennlp) (1.1.2)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.2.0-py3-none-any.whl (17 kB)
# Collecting tomli>=1.0.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from requests>=2.28->allennlp) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from requests>=2.28->allennlp) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from requests>=2.28->allennlp) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from requests>=2.28->allennlp) (1.26.16)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from scikit-learn>=1.0.1->allennlp) (3.1.0)
# Requirement already satisfied: thinc<7.1.0,>=7.0.2 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from spacy<3.4,>=2.1.0->allennlp) (7.0.8)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from spacy<3.4,>=2.1.0->allennlp) (2.0.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.0.12 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from spacy<3.4,>=2.1.0->allennlp) (0.10.1)
# Requirement already satisfied: srsly<1.1.0,>=0.0.5 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from spacy<3.4,>=2.1.0->allennlp) (1.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from spacy<3.4,>=2.1.0->allennlp) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from spacy<3.4,>=2.1.0->allennlp) (1.0.9)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from spacy<3.4,>=2.1.0->allennlp) (0.2.4)
# Requirement already satisfied: jsonschema<3.0.0,>=2.6.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from spacy<3.4,>=2.1.0->allennlp) (2.6.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from spacy<3.4,>=2.1.0->allennlp) (0.9.6)
# Requirement already satisfied: pillow>=4.1.1 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from torchvision<0.14.0,>=0.8.1->allennlp) (6.2.1)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 7.6 MB/s eta 0:00:0000:0100:01
# Collecting promise<3,>=2.0
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: psutil>=5.0.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (5.9.5)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.13.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.16.0)
# Requirement already satisfied: setuptools in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (65.6.3)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 8.0 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.28.0-py2.py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.2/213.2 kB 8.8 MB/s eta 0:00:00
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting datasets
#   Downloading datasets-2.13.0-py3-none-any.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 8.6 MB/s eta 0:00:00a 0:00:01
#   Using cached datasets-2.12.0-py3-none-any.whl (474 kB)
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 8.7 MB/s eta 0:00:00a 0:00:01
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 8.4 MB/s eta 0:00:00a 0:00:01
# Collecting aiohttp
#   Using cached aiohttp-3.8.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (948 kB)
# Collecting responses<0.19
#   Using cached responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting multiprocess
#   Using cached multiprocess-0.70.14-py37-none-any.whl (115 kB)
# Collecting fsspec[http]>=2021.11.1
#   Using cached fsspec-2023.1.0-py3-none-any.whl (143 kB)
# Collecting xxhash
#   Using cached xxhash-3.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
# Requirement already satisfied: pandas in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from datasets->allennlp-models) (1.3.5)
# Collecting pyarrow>=6.0.0
#   Downloading pyarrow-12.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.1/39.1 MB 7.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wcwidth>=0.2.5 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from ftfy->allennlp-models) (0.2.5)
# Requirement already satisfied: botocore<1.30.0,>=1.29.160 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.29.160)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.6.1)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.9.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.3.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (148 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from aiohttp->datasets->allennlp-models) (23.1.0)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
# Collecting asynctest==0.13.0
#   Using cached asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.21.0)
# Collecting google-cloud-core<3.0dev,>=2.3.0
#   Downloading google_cloud_core-2.3.3-py2.py3-none-any.whl (29 kB)
# Collecting google-resumable-media>=2.3.2
#   Downloading google_resumable_media-2.5.0-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 10.2 MB/s eta 0:00:00
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5
#   Downloading google_api_core-2.11.1-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.5/120.5 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from importlib-metadata->huggingface-hub>=0.0.16->allennlp) (3.15.0)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from rich<13.0,>=12.1->cached-path<1.2.0,>=1.1.3->allennlp) (2.11.2)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2017.3 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from pandas->datasets->allennlp-models) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from pandas->datasets->allennlp-models) (2.8.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2
#   Downloading googleapis_common_protos-1.59.1-py2.py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (5.3.1)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/manish/anaconda3/envs/askBert/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.5.0)
# Building wheels for collected packages: fairscale, jsonnet, word2number, promise, pathtools
#   Building wheel for fairscale (pyproject.toml) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.6-py3-none-any.whl size=307224 sha256=a93665f1232b614c0c7b29b606b9b4878ee700f62096deca47bbe8c1bf3d0add
#   Stored in directory: /home/manish/.cache/pip/wheels/0b/8c/fa/a9e102632bcb86e919561cf25ca1e0dd2ec67476f3a5544653
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.20.0-cp37-cp37m-linux_x86_64.whl size=6411336 sha256=c1473b3e1488d52fc5947110b1ab1e9e4f1a5b7f3b492ab6d9edae04efb37ec0
#   Stored in directory: /home/manish/.cache/pip/wheels/ff/05/53/51f8d7585f88cccd2936b5eac5f30f92a35d8b5869c0258217
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5566 sha256=1d8ef72f49e1d95dedbc6f38cf73cd04f3a1a18a7653496e5e9871e3089fffe5
#   Stored in directory: /home/manish/.cache/pip/wheels/0e/e1/0b/575d02bdf2c7ff9c9be5490db69e8d4e2e26b5523e295137eb
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21486 sha256=d4671c38263a011f5b6009dd5199ce78f0e6a678cc839761ef1b7856b29dfaba
#   Stored in directory: /home/manish/.cache/pip/wheels/9d/ad/15/e6d5c43a0f01b88ee5883bd249a18e09d72821e43b1c3e8187
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=6b481c3747113e0d82750e2ec88e6a68d905799736bd8c7fb612f924ce8be733
#   Stored in directory: /home/manish/.cache/pip/wheels/7b/d8/86/08d5794e37091c7a918e0bb3322b7b43af55bda3b665b81e05
# Successfully built fairscale jsonnet word2number promise pathtools
# Installing collected packages: word2number, tokenizers, py-rouge, pathtools, lmdb, jsonnet, commonmark, xxhash, torch, tomli, smmap, shortuuid, setproctitle, sentry-sdk, rich, pyyaml, protobuf, promise, numpy, multidict, more-itertools, iniconfig, google-crc32c, ftfy, fsspec, frozenlist, filelock, docker-pycreds, dill, conllu, base58, asynctest, async-timeout, yarl, scipy, responses, pyarrow, pluggy, multiprocess, huggingface-hub, h5py, googleapis-common-protos, google-resumable-media, gitdb, fairscale, aiosignal, typer, transformers, pytest, google-api-core, GitPython, aiohttp, wandb, google-cloud-core, google-cloud-storage, datasets, cached-path, allennlp, allennlp-models
#   Attempting uninstall: torch
#     Found existing installation: torch 1.7.1
#     Uninstalling torch-1.7.1:
#       Successfully uninstalled torch-1.7.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.10.1
#     Uninstalling protobuf-3.10.1:
#       Successfully uninstalled protobuf-3.10.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.17.3
#     Uninstalling numpy-1.17.3:
#       Successfully uninstalled numpy-1.17.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.3.1
#     Uninstalling scipy-1.3.1:
#       Successfully uninstalled scipy-1.3.1
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.9.0
#     Uninstalling h5py-2.9.0:
#       Successfully uninstalled h5py-2.9.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 2.3.0
#     Uninstalling transformers-2.3.0:
#       Successfully uninstalled transformers-2.3.0
# Successfully installed GitPython-3.1.32 aiohttp-3.8.4 aiosignal-1.3.1 allennlp-2.10.1 allennlp-models-2.10.1 async-timeout-4.0.2 asynctest-0.13.0 base58-2.1.1 cached-path-1.1.6 commonmark-0.9.1 conllu-4.4.2 datasets-2.10.1 dill-0.3.6 docker-pycreds-0.4.0 fairscale-0.4.6 filelock-3.7.1 frozenlist-1.3.3 fsspec-2023.1.0 ftfy-6.1.1 gitdb-4.0.10 google-api-core-2.11.1 google-cloud-core-2.3.3 google-cloud-storage-2.10.0 google-crc32c-1.5.0 google-resumable-media-2.5.0 googleapis-common-protos-1.59.1 h5py-3.8.0 huggingface-hub-0.10.1 iniconfig-2.0.0 jsonnet-0.20.0 lmdb-1.4.1 more-itertools-9.1.0 multidict-6.0.4 multiprocess-0.70.14 numpy-1.21.6 pathtools-0.1.2 pluggy-1.2.0 promise-2.3 protobuf-3.20.3 py-rouge-1.1 pyarrow-12.0.1 pytest-7.4.0 pyyaml-6.0 responses-0.18.0 rich-12.6.0 scipy-1.7.3 sentry-sdk-1.28.0 setproctitle-1.3.2 shortuuid-1.0.11 smmap-5.0.0 tokenizers-0.12.1 tomli-2.0.1 torch-1.12.1 transformers-4.20.1 typer-0.9.0 wandb-0.12.21 word2number-1.1 xxhash-3.2.0 yarl-1.9.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from allennlp.predictors.predictor import Predictor

model_url = "https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2020.02.27.tar.gz"
predictor = Predictor.from_path(model_url)

# %%
text = "Link awakens from a deep slumber and a mysterious voice guides him to discover what has become of the ruined country of Hyrule Kingdom. Link leaves the Shrine of Resurrection and looks out at Hyrule on top of the Great Plateau. Link then meets an Old Man by a campfire. The Old Man promises Link his Paraglider, which is the only way to get down from the plateau. However, he first wants Spirit Orbs from nearby Shrines, in particular the Oman Au Shrine, Ja Baij Shrine, Owa Daim Shrine, and the Keh Namut Shrine. After Link gets the spirit orbs, the Old Man appears, then mysteriously disappears, telling Link to meet him in the Temple of Time. The Old Man reveals himself as the spirit of the deceased King of Hyrule, King Rhoam. Link learns from King Rhoam that 100 years prior, a great evil known as the Calamity Ganon rose up and laid waste to the kingdom and its people. Unable to be defeated, it was sealed within Hyrule Castle, while the ruins of the land were ravaged by nature over time. Although trapped, the Calamity Ganon has grown in power, and Link must defeat it before it breaks free once more and destroys the world. The mysterious voice turns out to be Zelda, who is the daughter of King Rhoam."

_text = "After escaping the confines of the plateau, Link is directed to meet the wise Sheikah elder Impa, and learn about the Guardians and Divine Beasts: 10,000 years prior these machines were created and successfully used by another Hero and another Princess to defeat the Calamity Ganon. But throughout the ages, knowledge about the ancient technology was lost until excavations in Hyrule Kingdom brought them to light once more, coinciding with the expected return of Calamity Ganon a hundred years ago. The Guardians were reactivated and four Champions were chosen to control the Divine Beasts: the Zora princess Mipha, the Goron warrior Daruk, the Gerudo chief Urbosa, and the Rito archer Revali. All the while, Zelda was unsuccessfully trying to gain access to her own prophesied powers, accompanied on her quests by her knight, the Hylian Champion Link. When the Calamity Ganon ultimately attacked, it devastated the Kingdom of Hyrule Kingdom by taking control of the ancient machines and turning them against the Hyruleans. As a last resort, Zelda was able to place the gravely wounded Link in the Shrine of Resurrection and use her awoken sealing powers to trap herself with Calamity Ganon in Hyrule Castle."

_text = "As Link sets off on his quest to defeat Calamity Ganon, he is asked to investigate the fate of the Divine Beasts and their former Champions. His ultimate goal remains to reach the Calamity Ganon and free the trapped Zelda before the whole world is laid to waste. But with the entire Kingdom of Hyrule before him to explore, it is up to Link himself to decide how he wishes to fulfill his foretold role as the Hylian Champion, and to save Hyrule Kingdom."

prediction = predictor.predict(document=text)  # get prediction
print("Clusters:")
for cluster in prediction['clusters']:
    print(cluster)  # list of clusters (the indices of spaCy tokens)
# Out:
# Clusters:
# [[0, 0], [11, 11], [25, 25], [43, 43], [57, 57], [106, 106], [122, 122], [150, 150], [217, 217]]
# [[18, 23], [35, 35], [145, 145], [174, 175], [177, 177]]
# [[46, 48], [53, 55], [58, 58], [75, 75], [112, 114], [125, 125], [132, 134], [136, 136]]
# [[39, 41], [70, 71]]
# [[78, 103], [108, 110]]
# [[141, 148], [153, 154], [246, 247]]
# [[160, 167], [185, 185], [208, 210], [220, 220], [222, 222]]
# [[7, 9], [232, 234]]

# %%
print(prediction['document'])
# Out:
# ['Link', 'awakens', 'from', 'a', 'deep', 'slumber', 'and', 'a', 'mysterious', 'voice', 'guides', 'him', 'to', 'discover', 'what', 'has', 'become', 'of', 'the', 'ruined', 'country', 'of', 'Hyrule', 'Kingdom', '.', 'Link', 'leaves', 'the', 'Shrine', 'of', 'Resurrection', 'and', 'looks', 'out', 'at', 'Hyrule', 'on', 'top', 'of', 'the', 'Great', 'Plateau', '.', 'Link', 'then', 'meets', 'an', 'Old', 'Man', 'by', 'a', 'campfire', '.', 'The', 'Old', 'Man', 'promises', 'Link', 'his', 'Paraglider', ',', 'which', 'is', 'the', 'only', 'way', 'to', 'get', 'down', 'from', 'the', 'plateau', '.', 'However', ',', 'he', 'first', 'wants', 'Spirit', 'Orbs', 'from', 'nearby', 'Shrines', ',', 'in', 'particular', 'the', 'Oman', 'Au', 'Shrine', ',', 'Ja', 'Baij', 'Shrine', ',', 'Owa', 'Daim', 'Shrine', ',', 'and', 'the', 'Keh', 'Namut', 'Shrine', '.', 'After', 'Link', 'gets', 'the', 'spirit', 'orbs', ',', 'the', 'Old', 'Man', 'appears', ',', 'then', 'mysteriously', 'disappears', ',', 'telling', 'Link', 'to', 'meet', 'him', 'in', 'the', 'Temple', 'of', 'Time', '.', 'The', 'Old', 'Man', 'reveals', 'himself', 'as', 'the', 'spirit', 'of', 'the', 'deceased', 'King', 'of', 'Hyrule', ',', 'King', 'Rhoam', '.', 'Link', 'learns', 'from', 'King', 'Rhoam', 'that', '100', 'years', 'prior', ',', 'a', 'great', 'evil', 'known', 'as', 'the', 'Calamity', 'Ganon', 'rose', 'up', 'and', 'laid', 'waste', 'to', 'the', 'kingdom', 'and', 'its', 'people', '.', 'Unable', 'to', 'be', 'defeated', ',', 'it', 'was', 'sealed', 'within', 'Hyrule', 'Castle', ',', 'while', 'the', 'ruins', 'of', 'the', 'land', 'were', 'ravaged', 'by', 'nature', 'over', 'time', '.', 'Although', 'trapped', ',', 'the', 'Calamity', 'Ganon', 'has', 'grown', 'in', 'power', ',', 'and', 'Link', 'must', 'defeat', 'it', 'before', 'it', 'breaks', 'free', 'once', 'more', 'and', 'destroys', 'the', 'world', '.', 'The', 'mysterious', 'voice', 'turns', 'out', 'to', 'be', 'Zelda', ',', 'who', 'is', 'the', 'daughter', 'of', 'King', 'Rhoam', '.', '\n\n', 'After', 'escaping', 'the', 'confines', 'of', 'the', 'plateau', ',', 'Link', 'is', 'directed', 'to', 'meet', 'the', 'wise', 'Sheikah', 'elder', 'Impa', ',', 'and', 'learn', 'about', 'the', 'Guardians', 'and', 'Divine', 'Beasts', ':', '10,000', 'years', 'prior', 'these', 'machines', 'were', 'created', 'and', 'successfully', 'used', 'by', 'another', 'Hero', 'and', 'another', 'Princess', 'to', 'defeat', 'the', 'Calamity', 'Ganon', '.', 'But', 'throughout', 'the', 'ages', ',', 'knowledge', 'about', 'the', 'ancient', 'technology', 'was', 'lost', 'until', 'excavations', 'in', 'Hyrule', 'Kingdom', 'brought', 'them', 'to', 'light', 'once', 'more', ',', 'coinciding', 'with', 'the', 'expected', 'return', 'of', 'Calamity', 'Ganon', 'a', 'hundred', 'years', 'ago', '.', 'The', 'Guardians', 'were', 'reactivated', 'and', 'four', 'Champions', 'were', 'chosen', 'to', 'control', 'the', 'Divine', 'Beasts', ':', 'the', 'Zora', 'princess', 'Mipha', ',', 'the', 'Goron', 'warrior', 'Daruk', ',', 'the', 'Gerudo', 'chief', 'Urbosa', ',', 'and', 'the', 'Rito', 'archer', 'Revali', '.', 'All', 'the', 'while', ',', 'Zelda', 'was', 'unsuccessfully', 'trying', 'to', 'gain', 'access', 'to', 'her', 'own', 'prophesied', 'powers', ',', 'accompanied', 'on', 'her', 'quests', 'by', 'her', 'knight', ',', 'the', 'Hylian', 'Champion', 'Link', '.', 'When', 'the', 'Calamity', 'Ganon', 'ultimately', 'attacked', ',', 'it', 'devastated', 'the', 'Kingdom', 'of', 'Hyrule', 'Kingdom', 'by', 'taking', 'control', 'of', 'the', 'ancient', 'machines', 'and', 'turning', 'them', 'against', 'the', 'Hyruleans', '.', 'As', 'a', 'last', 'resort', ',', 'Zelda', 'was', 'able', 'to', 'place', 'the', 'gravely', 'wounded', 'Link', 'in', 'the', 'Shrine', 'of', 'Resurrection', 'and', 'use', 'her', 'awoken', 'sealing', 'powers', 'to', 'trap', 'herself', 'with', 'Calamity', 'Ganon', 'in', 'Hyrule', 'Castle', '.', '\n\n', 'As', 'Link', 'sets', 'off', 'on', 'his', 'quest', 'to', 'defeat', 'Calamity', 'Ganon', ',', 'he', 'is', 'asked', 'to ...

# %%
print('Coref resolved: ',predictor.coref_resolved(text))  # resolved text
# Out:
# Coref resolved:  Link awakens from a deep slumber and a mysterious voice guides Link to discover what has become of the ruined country of Hyrule Kingdom. Link leaves the Shrine of Resurrection and looks out at the ruined country of Hyrule Kingdom on top of the Great Plateau. Link then meets an Old Man by a campfire. an Old Man promises Link an Old Man's Paraglider, which is the only way to get down from the Great Plateau. However, an Old Man first wants Spirit Orbs from nearby Shrines, in particular the Oman Au Shrine, Ja Baij Shrine, Owa Daim Shrine, and the Keh Namut Shrine. After Link gets Spirit Orbs from nearby Shrines, in particular the Oman Au Shrine, Ja Baij Shrine, Owa Daim Shrine, and the Keh Namut Shrine, an Old Man appears, then mysteriously disappears, telling Link to meet an Old Man in the Temple of Time. an Old Man reveals an Old Man as the spirit of the deceased King of the ruined country of Hyrule Kingdom, King Rhoam. Link learns from the deceased King of Hyrule, King Rhoam that 100 years prior, a great evil known as the Calamity Ganon rose up and laid waste to the ruined country of Hyrule Kingdom and the ruined country of Hyrule Kingdom's people. Unable to be defeated, a great evil known as the Calamity Ganon was sealed within Hyrule Castle, while the ruins of the land were ravaged by nature over time. Although trapped, a great evil known as the Calamity Ganon has grown in power, and Link must defeat a great evil known as the Calamity Ganon before a great evil known as the Calamity Ganon breaks free once more and destroys the world. a mysterious voice turns out to be Zelda, who is the daughter of the deceased King of Hyrule, King Rhoam.
