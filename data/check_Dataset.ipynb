# %%
# %pip install pandas xlrd openpyxl numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 6.1 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_excel('Sander/ElderScrollsOnlineDataset.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2020 entries, 0 to 2019
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2020 non-null   object
#  1   level           627 non-null    object
#  2   objective       2020 non-null   object
#  3   quest_type      1957 non-null   object
#  4   faction         640 non-null    object
#  5   repeatable      318 non-null    object
#  6   quest_giver     1975 non-null   object
#  7   location        1913 non-null   object
#  8   previous_quest  218 non-null    object
#  9   concurrent      162 non-null    object
#  10  next_quest      687 non-null    object
#  11  description     2020 non-null   object
# dtypes: object(12)
# memory usage: 189.5+ KB

# %%
df.head()
# Out:
#                       title level  \
# 0              Abominations   NaN
# 1  Abominations from Beyond   NaN
# 2  An Abundance of Stibbons   NaN
# 3     The Abyssal Alchemist   NaN
# 4         The Abyssal Cabal   NaN
#
#                                            objective quest_type  faction  \
# 0  Burn the bodies of two Weynon villagers before...       Side      NaN
# 1  Rescue a group of locals held captive by the u...       Side      NaN
# 2  Assist Lady Laurent in restoring order, and re...       Side      NaN
# 3  Clear out Welenkin Cove and eliminate the Sea ...       Side      NaN
# 4          Further investigate the Sea Sload threat.       Side  Neutral
#
#   repeatable                             quest_giver    location  \
# 0      Daily                                    Mael    Cyrodiil
# 1        NaN                       Priestess Pietine  Stormhaven
# 2        NaN  Lounges-on-Moss, Lady Clarisse Laurent   Blackwood
# ...

# %%
df = df.drop(['level', 'faction', 'repeatable'], axis=1)

# %%
df.query('quest_type == "Main"')
# Out:
#                                title  \
# 176                   Bound in Blood
# 195         Bright Moons, Warm Sands
# 198                     Broken Bonds
# 223                   Cadwell's Gold
# 224                 Cadwell's Silver
# 244              Castle of the Worm
# 262                  Chasing Shadows
# 318   Council of the Five Companions
# 385               Daughter of Giants
# 646             The Gates of Adamant
# 681                   God of Schemes
# 725                Halls of Torment
# 1521            Shadow of Sancre Tor
# 1732                The Tharn Speaks
# 1896                Valley of Blades
#
#                                               objective quest_type  \
# 176   Escape captivity at the hands of the Icereach ...       Main
# 195   Survive the Dragon attack in Star Haven Adepto...       Main
# 198   Escape your slaver captors on the island of Fi...       Main
# 223   Use Meridia's blessing to explore a third alli...       Main
# ...

# %%
df = pd.read_json('RPGQuests/data_set/data_set/TES/quests_oblivion.json')

# %%
desc0 = df.description[0]

# %%
print(desc0)
# Out:
# Dead Drop Orders #6
# by Lucien Lachance
#
# Alval Uvani is dead, just like all the others. You continue to impress me, Silencer, and I am only too eager to indulge your homicidal instincts.
# Your next target is a savage Nord barbarian, living alone and exposed at a small campsite on the summit of Gnoll Mountain. This barbarian, Havilstein Hoar-Blood by name, savagely butchered the chieftain of a mead hall on the island of Solstheim. The chieftain's sister has forgone the Nord custom of extracting the monetary retribution of wergild, and instead wants Hoar-Blood to pay with his life. You, dear Silencer, will help put her family at peace.
# You are to go to Gnoll Mountain, locate Havilstein Hoar-Blood, and send his soul to the great beyond.
# ...
